# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
order_x_report = pd.read_excel('/content/Company X - Order Report.xlsx')
pincode_x_zones = pd.read_excel('/content/Company X - Pincode Zones.xlsx')
sku_x_master = pd.read_excel('/content/Company X - SKU Master.xlsx')
invoice = pd.read_excel('/content/Courier Company - Invoice.xlsx')
rates = pd.read_excel('/content/Courier Company - Rates.xlsx')

# %%
order_x_report
# Out:
#      ExternOrderNo            SKU  Order Qty
# 0       2001827036  8904223818706        1.0
# 1       2001827036  8904223819093        1.0
# 2       2001827036  8904223819109        1.0
# 3       2001827036  8904223818430        1.0
# 4       2001827036  8904223819277        1.0
# ..             ...            ...        ...
# 395     2001806229  8904223818942        1.0
# 396     2001806229  8904223818850        1.0
# 397     2001806226  8904223818850        2.0
# 398     2001806210  8904223816214        1.0
# 399     2001806210  8904223818874        1.0
#
# [400 rows x 3 columns]

# %%
pincode_x_zones
# Out:
#      Warehouse Pincode  Customer Pincode Zone
# 0               121003            507101    d
# 1               121003            486886    d
# 2               121003            532484    d
# 3               121003            143001    b
# 4               121003            515591    d
# ..                 ...               ...  ...
# 119             121003            325207    b
# 120             121003            303702    b
# 121             121003            313301    b
# 122             121003            173212    e
# 123             121003            302020    b
#
# [124 rows x 3 columns]

# %%
sku_x_master
# Out:
#               SKU  Weight (g)
# 0   8904223815682         210
# 1   8904223815859         165
# 2   8904223815866         113
# 3   8904223815873          65
# 4   8904223816214         120
# ..            ...         ...
# 61  8904223819505         210
# 62  8904223819499         210
# 63  8904223819512         210
# 64  8904223819543         300
# 65     SACHETS001          10
#
# [66 rows x 2 columns]

# %%
invoice
# Out:
#           AWB Code    Order ID  Charged Weight  Warehouse Pincode  \
# 0    1091117222124  2001806232            1.30             121003
# 1    1091117222194  2001806273            1.00             121003
# 2    1091117222931  2001806408            2.50             121003
# 3    1091117223244  2001806458            1.00             121003
# 4    1091117229345  2001807012            0.15             121003
# ..             ...         ...             ...                ...
# 119  1091118551656  2001812941            0.73             121003
# 120  1091117614452  2001809383            0.50             121003
# 121  1091120922803  2001820978            0.50             121003
# 122  1091121844806  2001811475            0.50             121003
# 123  1091121846136  2001811305            0.50             121003
#
#      Customer Pincode Zone         Type of Shipment  Billing Amount (Rs.)
# 0              507101    d          Forward charges                 135.0
# ...

# %%
rates
# Out:
#    fwd_a_fixed  fwd_a_additional  fwd_b_fixed  fwd_b_additional  fwd_c_fixed  \
# 0         29.5              23.6           33              28.3         40.1
#
#    fwd_c_additional  fwd_d_fixed  fwd_d_additional  fwd_e_fixed  \
# 0              38.9         45.4              44.8         56.6
#
#    fwd_e_additional  rto_a_fixed  rto_a_additional  rto_b_fixed  \
# 0              55.5         13.6              23.6         20.5
#
#    rto_b_additional  rto_c_fixed  rto_c_additional  rto_d_fixed  \
# 0              28.3         31.9              38.9         41.3
#
#    rto_d_additional  rto_e_fixed  rto_e_additional
# 0              44.8         50.7              55.5

# %% [markdown]
# OUTPUT DATA 1

# %%
invoice['Order ID'].nunique()
# Out:
# 124

# %%
invoice['AWB Code'].nunique()
# Out:
# 124

# %%
df = invoice[['Order ID','AWB Code']]
df
# Out:
#        Order ID       AWB Code
# 0    2001806232  1091117222124
# 1    2001806273  1091117222194
# 2    2001806408  1091117222931
# 3    2001806458  1091117223244
# 4    2001807012  1091117229345
# ..          ...            ...
# 119  2001812941  1091118551656
# 120  2001809383  1091117614452
# 121  2001820978  1091120922803
# 122  2001811475  1091121844806
# 123  2001811305  1091121846136
#
# [124 rows x 2 columns]

# %%
sku_x_master.head()
# Out:
#              SKU  Weight (g)
# 0  8904223815682         210
# 1  8904223815859         165
# 2  8904223815866         113
# 3  8904223815873          65
# 4  8904223816214         120

# %%
order_x_report.head()
# Out:
#    ExternOrderNo            SKU  Order Qty
# 0     2001827036  8904223818706        1.0
# 1     2001827036  8904223819093        1.0
# 2     2001827036  8904223819109        1.0
# 3     2001827036  8904223818430        1.0
# 4     2001827036  8904223819277        1.0

# %%
order_x_report['SKU'].nunique()
# Out:
# 65

# %%
sku_x_master['SKU'].nunique()
# Out:
# 65

# %%
sku_x_new = pd.merge(order_x_report,sku_x_master,on='SKU',how = 'left')

# %%
sku_x_new
# Out:
#      ExternOrderNo            SKU  Order Qty  Weight (g)
# 0       2001827036  8904223818706        1.0         127
# 1       2001827036  8904223819093        1.0         150
# 2       2001827036  8904223819109        1.0         100
# 3       2001827036  8904223818430        1.0         165
# 4       2001827036  8904223819277        1.0         350
# ..             ...            ...        ...         ...
# 396     2001806229  8904223818942        1.0         133
# 397     2001806229  8904223818850        1.0         240
# 398     2001806226  8904223818850        2.0         240
# 399     2001806210  8904223816214        1.0         120
# 400     2001806210  8904223818874        1.0         100
#
# [401 rows x 4 columns]

# %%
sku_x_new['Total Weight(G)']  = sku_x_new['Order Qty']* sku_x_new['Weight (g)']

# %%
sku_x_new
# Out:
#      ExternOrderNo            SKU  Order Qty  Weight (g)  Total Weight(G)
# 0       2001827036  8904223818706        1.0         127            127.0
# 1       2001827036  8904223819093        1.0         150            150.0
# 2       2001827036  8904223819109        1.0         100            100.0
# 3       2001827036  8904223818430        1.0         165            165.0
# 4       2001827036  8904223819277        1.0         350            350.0
# ..             ...            ...        ...         ...              ...
# 396     2001806229  8904223818942        1.0         133            133.0
# 397     2001806229  8904223818850        1.0         240            240.0
# 398     2001806226  8904223818850        2.0         240            480.0
# 399     2001806210  8904223816214        1.0         120            120.0
# 400     2001806210  8904223818874        1.0         100            100.0
#
# [401 rows x 5 columns]

# %%
sku_x_new['Total Weight X (KG)'] = sku_x_new['Total Weight(G)']/1000

# %%
sku_x_new
# Out:
#      ExternOrderNo            SKU  Order Qty  Weight (g)  Total Weight(G)  \
# 0       2001827036  8904223818706        1.0         127            127.0
# 1       2001827036  8904223819093        1.0         150            150.0
# 2       2001827036  8904223819109        1.0         100            100.0
# 3       2001827036  8904223818430        1.0         165            165.0
# 4       2001827036  8904223819277        1.0         350            350.0
# ..             ...            ...        ...         ...              ...
# 396     2001806229  8904223818942        1.0         133            133.0
# 397     2001806229  8904223818850        1.0         240            240.0
# 398     2001806226  8904223818850        2.0         240            480.0
# 399     2001806210  8904223816214        1.0         120            120.0
# 400     2001806210  8904223818874        1.0         100            100.0
#
#      Total Weight X (KG)
# 0                  0.127
# 1                  0.150
# ...

# %%
sku_x_new.drop(['Total Weight(G)'],axis=1,inplace=True)

# %%
sku_x_new
# Out:
#      ExternOrderNo            SKU  Order Qty  Weight (g)  Total Weight X (KG)
# 0       2001827036  8904223818706        1.0         127                0.127
# 1       2001827036  8904223819093        1.0         150                0.150
# 2       2001827036  8904223819109        1.0         100                0.100
# 3       2001827036  8904223818430        1.0         165                0.165
# 4       2001827036  8904223819277        1.0         350                0.350
# ..             ...            ...        ...         ...                  ...
# 396     2001806229  8904223818942        1.0         133                0.133
# 397     2001806229  8904223818850        1.0         240                0.240
# 398     2001806226  8904223818850        2.0         240                0.480
# 399     2001806210  8904223816214        1.0         120                0.120
# 400     2001806210  8904223818874        1.0         100                0.100
#
# [401 rows x 5 columns]

# %%
sku_x_newgrouped = sku_x_new.groupby('ExternOrderNo').agg({'Total Weight X (KG)': 'sum'})

# %%
sku_x_newgrouped.reset_index(inplace = True)

# %%
sku_x_newgrouped
# Out:
#      ExternOrderNo  Total Weight X (KG)
# 0       2001806210                0.220
# 1       2001806226                0.480
# 2       2001806229                0.500
# 3       2001806232                1.302
# 4       2001806233                0.245
# ..             ...                  ...
# 119     2001821995                0.477
# 120     2001822466                1.376
# 121     2001823564                0.672
# 122     2001825261                1.557
# 123     2001827036                2.176
#
# [124 rows x 2 columns]

# %%
sku_x_newgrouped.rename(columns={'ExternOrderNo':'Order ID'},inplace=True)

# %%
sku_x_newgrouped
# Out:
#        Order ID  Total Weight X (KG)
# 0    2001806210                0.220
# 1    2001806226                0.480
# 2    2001806229                0.500
# 3    2001806232                1.302
# 4    2001806233                0.245
# ..          ...                  ...
# 119  2001821995                0.477
# 120  2001822466                1.376
# 121  2001823564                0.672
# 122  2001825261                1.557
# 123  2001827036                2.176
#
# [124 rows x 2 columns]

# %%
df1=pd.merge(df,sku_x_newgrouped,on='Order ID',how='left')

# %%
df1
# Out:
#        Order ID       AWB Code  Total Weight X (KG)
# 0    2001806232  1091117222124                1.302
# 1    2001806273  1091117222194                0.615
# 2    2001806408  1091117222931                2.265
# 3    2001806458  1091117223244                0.700
# 4    2001807012  1091117229345                0.240
# ..          ...            ...                  ...
# 119  2001812941  1091118551656                0.500
# 120  2001809383  1091117614452                0.607
# 121  2001820978  1091120922803                0.515
# 122  2001811475  1091121844806                0.689
# 123  2001811305  1091121846136                0.750
#
# [124 rows x 3 columns]

# %%
df1['Weight Slab X(KG)']=np.ceil(df1['Total Weight X (KG)']/0.5)*0.5

# %%
df1
# Out:
#        Order ID       AWB Code  Total Weight X (KG)  Weight Slab X(KG)
# 0    2001806232  1091117222124                1.302                1.5
# 1    2001806273  1091117222194                0.615                1.0
# 2    2001806408  1091117222931                2.265                2.5
# 3    2001806458  1091117223244                0.700                1.0
# 4    2001807012  1091117229345                0.240                0.5
# ..          ...            ...                  ...                ...
# 119  2001812941  1091118551656                0.500                0.5
# 120  2001809383  1091117614452                0.607                1.0
# 121  2001820978  1091120922803                0.515                1.0
# 122  2001811475  1091121844806                0.689                1.0
# 123  2001811305  1091121846136                0.750                1.0
#
# [124 rows x 4 columns]

# %%
invoice
# Out:
#           AWB Code    Order ID  Charged Weight  Warehouse Pincode  \
# 0    1091117222124  2001806232            1.30             121003
# 1    1091117222194  2001806273            1.00             121003
# 2    1091117222931  2001806408            2.50             121003
# 3    1091117223244  2001806458            1.00             121003
# 4    1091117229345  2001807012            0.15             121003
# ..             ...         ...             ...                ...
# 119  1091118551656  2001812941            0.73             121003
# 120  1091117614452  2001809383            0.50             121003
# 121  1091120922803  2001820978            0.50             121003
# 122  1091121844806  2001811475            0.50             121003
# 123  1091121846136  2001811305            0.50             121003
#
#      Customer Pincode Zone         Type of Shipment  Billing Amount (Rs.)
# 0              507101    d          Forward charges                 135.0
# ...

# %%
df1['Total Weight CC(KG)']=invoice['Charged Weight']

# %%
df1
# Out:
#        Order ID       AWB Code  Total Weight X (KG)  Weight Slab X(KG)  \
# 0    2001806232  1091117222124                1.302                1.5
# 1    2001806273  1091117222194                0.615                1.0
# 2    2001806408  1091117222931                2.265                2.5
# 3    2001806458  1091117223244                0.700                1.0
# 4    2001807012  1091117229345                0.240                0.5
# ..          ...            ...                  ...                ...
# 119  2001812941  1091118551656                0.500                0.5
# 120  2001809383  1091117614452                0.607                1.0
# 121  2001820978  1091120922803                0.515                1.0
# 122  2001811475  1091121844806                0.689                1.0
# 123  2001811305  1091121846136                0.750                1.0
#
#      Total Weight CC(KG)
# 0                   1.30
# 1                   1.00
# 2                   2.50
# ...

# %%
df1['Weight Slab CC(KG)']=np.ceil(df1['Total Weight CC(KG)']/0.5)*0.5

# %%
df1
# Out:
#        Order ID       AWB Code  Total Weight X (KG)  Weight Slab X(KG)  \
# 0    2001806232  1091117222124                1.302                1.5
# 1    2001806273  1091117222194                0.615                1.0
# 2    2001806408  1091117222931                2.265                2.5
# 3    2001806458  1091117223244                0.700                1.0
# 4    2001807012  1091117229345                0.240                0.5
# ..          ...            ...                  ...                ...
# 119  2001812941  1091118551656                0.500                0.5
# 120  2001809383  1091117614452                0.607                1.0
# 121  2001820978  1091120922803                0.515                1.0
# 122  2001811475  1091121844806                0.689                1.0
# 123  2001811305  1091121846136                0.750                1.0
#
#      Total Weight CC(KG)  Weight Slab CC(KG)
# 0                   1.30                 1.5
# ...

# %%
invoice
# Out:
#           AWB Code    Order ID  Charged Weight  Warehouse Pincode  \
# 0    1091117222124  2001806232            1.30             121003
# 1    1091117222194  2001806273            1.00             121003
# 2    1091117222931  2001806408            2.50             121003
# 3    1091117223244  2001806458            1.00             121003
# 4    1091117229345  2001807012            0.15             121003
# ..             ...         ...             ...                ...
# 119  1091118551656  2001812941            0.73             121003
# 120  1091117614452  2001809383            0.50             121003
# 121  1091120922803  2001820978            0.50             121003
# 122  1091121844806  2001811475            0.50             121003
# 123  1091121846136  2001811305            0.50             121003
#
#      Customer Pincode Zone         Type of Shipment  Billing Amount (Rs.)
# 0              507101    d          Forward charges                 135.0
# ...

# %%
pincode_x_zones_unique = pincode_x_zones.drop_duplicates()

# %%
# pincode_x_zones['Warehouse Pincode'].unique()

# %%
# pincode_x_zones_unique

# %%
merge = pd.merge(pincode_x_zones_unique,invoice,on=['Warehouse Pincode', 'Customer Pincode'],how='left')

# %%
merge
# Out:
#      Warehouse Pincode  Customer Pincode Zone_x       AWB Code    Order ID  \
# 0               121003            507101      d  1091117222124  2001806232
# 1               121003            486886      d  1091117222194  2001806273
# 2               121003            532484      d  1091117222931  2001806408
# 3               121003            143001      b  1091117223244  2001806458
# 4               121003            515591      d  1091117229345  2001807012
# ..                 ...               ...    ...            ...         ...
# 119             121003            302020      b  1091117904860  2001811039
# 120             121003            302020      b  1091121846136  2001811305
# 121             121003            325207      b  1091118551656  2001812941
# 122             121003            303702      b  1091117614452  2001809383
# 123             121003            313301      b  1091120922803  2001820978
#
# ...

# %%
df1 = pd.merge(df1,merge,on='Order ID',how='left')

# %%
df1
# Out:
#        Order ID     AWB Code_x  Total Weight X (KG)  Weight Slab X(KG)  \
# 0    2001806232  1091117222124                1.302                1.5
# 1    2001806273  1091117222194                0.615                1.0
# 2    2001806408  1091117222931                2.265                2.5
# 3    2001806458  1091117223244                0.700                1.0
# 4    2001807012  1091117229345                0.240                0.5
# ..          ...            ...                  ...                ...
# 119  2001812941  1091118551656                0.500                0.5
# 120  2001809383  1091117614452                0.607                1.0
# 121  2001820978  1091120922803                0.515                1.0
# 122  2001811475  1091121844806                0.689                1.0
# 123  2001811305  1091121846136                0.750                1.0
#
#      Total Weight CC(KG)  Weight Slab CC(KG)  Warehouse Pincode  \
# ...

# %%
df1.drop(['AWB Code_y','Charged Weight'],axis=1,inplace=True)

# %%
df1
# Out:
#        Order ID     AWB Code_x  Total Weight X (KG)  Weight Slab X(KG)  \
# 0    2001806232  1091117222124                1.302                1.5
# 1    2001806273  1091117222194                0.615                1.0
# 2    2001806408  1091117222931                2.265                2.5
# 3    2001806458  1091117223244                0.700                1.0
# 4    2001807012  1091117229345                0.240                0.5
# ..          ...            ...                  ...                ...
# 119  2001812941  1091118551656                0.500                0.5
# 120  2001809383  1091117614452                0.607                1.0
# 121  2001820978  1091120922803                0.515                1.0
# 122  2001811475  1091121844806                0.689                1.0
# 123  2001811305  1091121846136                0.750                1.0
#
#      Total Weight CC(KG)  Weight Slab CC(KG)  Warehouse Pincode  \
# ...

# %%
df1.rename(columns={'AWB Code_x':'AWB'},inplace=True)

# %%
df1.rename(columns={'Zone_x':'Zone as per X'},inplace=True)

# %%
df1.rename(columns={'Zone_y':'Zone as per CC'},inplace=True)

# %%
df1.columns
# Out:
# Index(['Order ID', 'AWB', 'Total Weight X (KG)', 'Weight Slab X(KG)',
#        'Total Weight CC(KG)', 'Weight Slab CC(KG)', 'Warehouse Pincode',
#        'Customer Pincode', 'Zone as per X', 'Zone as per CC',
#        'Type of Shipment', 'Billing Amount (Rs.)'],
#       dtype='object')

# %%
rates_new = rates.T.reset_index()

# %%
rates_new.rename(columns={'index':'key',0:'Rate'}, inplace = True)

# %%
rates_new
# Out:
#                  key  Rate
# 0        fwd_a_fixed  29.5
# 1   fwd_a_additional  23.6
# 2        fwd_b_fixed  33.0
# 3   fwd_b_additional  28.3
# 4        fwd_c_fixed  40.1
# 5   fwd_c_additional  38.9
# 6        fwd_d_fixed  45.4
# 7   fwd_d_additional  44.8
# 8        fwd_e_fixed  56.6
# 9   fwd_e_additional  55.5
# 10       rto_a_fixed  13.6
# 11  rto_a_additional  23.6
# 12       rto_b_fixed  20.5
# 13  rto_b_additional  28.3
# 14       rto_c_fixed  31.9
# 15  rto_c_additional  38.9
# 16       rto_d_fixed  41.3
# 17  rto_d_additional  44.8
# 18       rto_e_fixed  50.7
# 19  rto_e_additional  55.5

# %% [markdown]
# Expected Billing rate

# %%
df1['fwd_fixed_zone_key'] = 'fwd_' + df1['Zone as per X'] + '_fixed'

# %%
df1 = pd.merge(df1, rates_new, left_on = 'fwd_fixed_zone_key', right_on = 'key', how = 'left')

# %%
df1.rename(columns = {"Rate":'Fixed zone rate'}, inplace = True)

# %%
df1.drop('key', axis = 1, inplace = True)

# %%
df1
# Out:
#        Order ID            AWB  Total Weight X (KG)  Weight Slab X(KG)  \
# 0    2001806232  1091117222124                1.302                1.5
# 1    2001806273  1091117222194                0.615                1.0
# 2    2001806408  1091117222931                2.265                2.5
# 3    2001806458  1091117223244                0.700                1.0
# 4    2001807012  1091117229345                0.240                0.5
# ..          ...            ...                  ...                ...
# 119  2001812941  1091118551656                0.500                0.5
# 120  2001809383  1091117614452                0.607                1.0
# 121  2001820978  1091120922803                0.515                1.0
# 122  2001811475  1091121844806                0.689                1.0
# 123  2001811305  1091121846136                0.750                1.0
#
#      Total Weight CC(KG)  Weight Slab CC(KG)  Warehouse Pincode  \
# ...

# %%
df1['fwd_add_zone_key'] = 'fwd_' + df1['Zone as per X'] + '_additional'

# %%
df1 = pd.merge(df1, rates_new, left_on = 'fwd_add_zone_key', right_on = 'key', how = 'left')

# %%
df1.rename(columns = {"Rate":'Additional zone rate'}, inplace = True)

# %%
df1.drop('key', axis = 1, inplace = True)

# %%
df1['rto_fixed_zone_key'] = 'rto_' + df1['Zone as per X'] + '_fixed'

# %%
df1 = pd.merge(df1, rates_new, left_on = 'rto_fixed_zone_key', right_on = 'key', how = 'left')

# %%
df1.rename(columns = {"Rate":'Fixed Rto zone rate'}, inplace = True)

# %%
df1.drop('key', axis = 1, inplace = True)

# %%
df1['rto_add_zone_key'] = 'rto_' + df1['Zone as per X'] + '_additional'

# %%
df1 = pd.merge(df1, rates_new, left_on = 'rto_add_zone_key', right_on = 'key', how = 'left')

# %%
df1.rename(columns = {"Rate":'Additional Rto zone rate'}, inplace = True)

# %%
df1.drop('key', axis = 1, inplace = True)

# %%
df1
# Out:
#        Order ID            AWB  Total Weight X (KG)  Weight Slab X(KG)  \
# 0    2001806232  1091117222124                1.302                1.5
# 1    2001806273  1091117222194                0.615                1.0
# 2    2001806408  1091117222931                2.265                2.5
# 3    2001806458  1091117223244                0.700                1.0
# 4    2001807012  1091117229345                0.240                0.5
# ..          ...            ...                  ...                ...
# 119  2001812941  1091118551656                0.500                0.5
# 120  2001809383  1091117614452                0.607                1.0
# 121  2001820978  1091120922803                0.515                1.0
# 122  2001811475  1091121844806                0.689                1.0
# 123  2001811305  1091121846136                0.750                1.0
#
#      Total Weight CC(KG)  Weight Slab CC(KG)  Warehouse Pincode  \
# ...

# %%
df1['Type of Shipment'].unique()
# Out:
# array(['Forward charges', 'Forward and RTO charges'], dtype=object)

# %%
df1['Fixed Rto zone rate'] = np.where(df1['Type of Shipment'] == 'Forward charges', 0, df1['Fixed Rto zone rate'])
df1['Additional Rto zone rate'] = np.where(df1['Type of Shipment'] == 'Forward charges', 0, df1['Additional Rto zone rate'])

# %%
df1
# Out:
#        Order ID            AWB  Total Weight X (KG)  Weight Slab X(KG)  \
# 0    2001806232  1091117222124                1.302                1.5
# 1    2001806273  1091117222194                0.615                1.0
# 2    2001806408  1091117222931                2.265                2.5
# 3    2001806458  1091117223244                0.700                1.0
# 4    2001807012  1091117229345                0.240                0.5
# ..          ...            ...                  ...                ...
# 119  2001812941  1091118551656                0.500                0.5
# 120  2001809383  1091117614452                0.607                1.0
# 121  2001820978  1091120922803                0.515                1.0
# 122  2001811475  1091121844806                0.689                1.0
# 123  2001811305  1091121846136                0.750                1.0
#
#      Total Weight CC(KG)  Weight Slab CC(KG)  Warehouse Pincode  \
# ...

# %%
# expected price = fixed_zone_rate + additional_zone_rate*(weight_slab - 0.5)*2 + Fixed Rto zone rate + Additional Rto zone rate*(weight_slab - 0.5)*2

# %%
df1['Expected Bill X'] = df1['Fixed zone rate'] + (df1['Additional zone rate']*(df1['Weight Slab X(KG)']-0.5)*2) + df1['Fixed Rto zone rate'] + (df1['Additional Rto zone rate']*(df1['Weight Slab X(KG)']-0.5)*2)

# %%
df1.columns
# Out:
# Index(['Order ID', 'AWB', 'Total Weight X (KG)', 'Weight Slab X(KG)',
#        'Total Weight CC(KG)', 'Weight Slab CC(KG)', 'Warehouse Pincode',
#        'Customer Pincode', 'Zone as per X', 'Zone as per CC',
#        'Type of Shipment', 'Billing Amount (Rs.)', 'fwd_fixed_zone_key',
#        'Fixed zone rate', 'fwd_add_zone_key', 'Additional zone rate',
#        'rto_fixed_zone_key', 'Fixed Rto zone rate', 'rto_add_zone_key',
#        'Additional Rto zone rate', 'Expected Bill X'],
#       dtype='object')

# %%
final_df = df1.drop(['fwd_fixed_zone_key',
       'Fixed zone rate', 'fwd_add_zone_key', 'Additional zone rate',
       'rto_fixed_zone_key', 'Fixed Rto zone rate', 'rto_add_zone_key',
       'Additional Rto zone rate'], axis = 1)

# %%
final_df
# Out:
#        Order ID            AWB  Total Weight X (KG)  Weight Slab X(KG)  \
# 0    2001806232  1091117222124                1.302                1.5
# 1    2001806273  1091117222194                0.615                1.0
# 2    2001806408  1091117222931                2.265                2.5
# 3    2001806458  1091117223244                0.700                1.0
# 4    2001807012  1091117229345                0.240                0.5
# ..          ...            ...                  ...                ...
# 119  2001812941  1091118551656                0.500                0.5
# 120  2001809383  1091117614452                0.607                1.0
# 121  2001820978  1091120922803                0.515                1.0
# 122  2001811475  1091121844806                0.689                1.0
# 123  2001811305  1091121846136                0.750                1.0
#
#      Total Weight CC(KG)  Weight Slab CC(KG)  Warehouse Pincode  \
# ...

# %%
final_df['Bill Difference'] = final_df['Expected Bill X'].round(2) - final_df['Billing Amount (Rs.)'].round(2)
final_df
# Out:
#        Order ID            AWB  Total Weight X (KG)  Weight Slab X(KG)  \
# 0    2001806232  1091117222124                1.302                1.5
# 1    2001806273  1091117222194                0.615                1.0
# 2    2001806408  1091117222931                2.265                2.5
# 3    2001806458  1091117223244                0.700                1.0
# 4    2001807012  1091117229345                0.240                0.5
# ..          ...            ...                  ...                ...
# 119  2001812941  1091118551656                0.500                0.5
# 120  2001809383  1091117614452                0.607                1.0
# 121  2001820978  1091120922803                0.515                1.0
# 122  2001811475  1091121844806                0.689                1.0
# 123  2001811305  1091121846136                0.750                1.0
#
#      Total Weight CC(KG)  Weight Slab CC(KG)  Warehouse Pincode  \
# ...

# %%
final_df.to_csv('Resultant Table.csv')

# %% [markdown]
# OUTPUT DATA 2

# %%
final_df['Result'] = np.where(final_df['Bill Difference'] == 0, 'Correctly Charged',
                             np.where(final_df['Bill Difference']>0, 'Under Charged',
                                     np.where(final_df['Bill Difference']<0, 'Over Charged', None)))

# %%
final_df['Result'].unique()
# Out:
# array(['Correctly Charged', 'Under Charged', 'Over Charged'], dtype=object)

# %%
final_summary = final_df.groupby('Result').agg({'Order ID':'count', 'Billing Amount (Rs.)':'sum'})

# %%
final_summary.reset_index(inplace = True)

# %%
final_summary
# Out:
#               Result  Order ID  Billing Amount (Rs.)
# 0  Correctly Charged        22                1826.9
# 1       Over Charged        79                8469.8
# 2      Under Charged        23                3351.5

# %%
final_summary.to_csv('Summary Table.csv')
