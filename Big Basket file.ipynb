# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("C:/Users/Vivek Singh/OneDrive/Desktop/BigBasket Products.csv")

# %%
df
# Out:
#        index                                            product  \
# 0          1             Garlic Oil - Vegetarian Capsule 500 mg
# 1          2                              Water Bottle - Orange
# 2          3                     Brass Angle Deep - Plain, No.2
# 3          4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4          5                 Creme Soft Soap - For Hands & Body
# ...      ...                                                ...
# 27550  27551         Wottagirl! Perfume Spray - Heaven, Classic
# 27551  27552                                           Rosemary
# 27552  27553                       Peri-Peri Sweet Potato Chips
# 27553  27554                          Green Tea - Pure Original
# 27554  27555                     United Dreams Go Far Deodorant
#
#                      category              sub_category  \
# 0            Beauty & Hygiene                 Hair Care
# 1      Kitchen, Garden & Pets     Storage & Accessories
# ...

# %%
df.drop('index',axis=1,inplace=True)

# %%
df
# Out:
#                                                  product  \
# 0                 Garlic Oil - Vegetarian Capsule 500 mg
# 2                         Brass Angle Deep - Plain, No.2
# 3      Cereal Flip Lid Container/Storage Jar - Assort...
# 4                     Creme Soft Soap - For Hands & Body
# 5                      Germ - Removal Multipurpose Wipes
# ...                                                  ...
# 27550         Wottagirl! Perfume Spray - Heaven, Classic
# 27551                                           Rosemary
# 27552                       Peri-Peri Sweet Potato Chips
# 27553                          Green Tea - Pure Original
# 27554                     United Dreams Go Far Deodorant
#
#                    category              sub_category  \
# 0          Beauty & Hygiene                 Hair Care
# 2      Cleaning & Household               Pooja Needs
# 3      Cleaning & Household      Bins & Bathroom Ware
# 4          Beauty & Hygiene          Bath & Hand Wash
# ...

# %%
sns.boxplot(df.sale_price,orient='h')
# Out:
# <Axes: xlabel='sale_price'>

# %%
Q1,Q3 = df.sale_price.quantile([0,1])

# %%
Q1,Q3
# Out:
# (2.45, 112475.0)

# %%
IQR = Q3-Q1

# %%
IQR
# Out:
# 112472.55

# %%
UL = Q3+1.5*(IQR)
LL = Q1-1.5*(IQR)

# %%
UL,LL
# Out:
# (281183.825, -168706.375)

# %%
df.sale_price.max()
# Out:
# 112475.0

# %%
df.sale_price.min()
# Out:
# 2.45

# %%
df.sale_price = np.where(df.sale_price>UL,UL,df.sale_price)

# %%
df
# Out:
#                                                  product  \
# 0                 Garlic Oil - Vegetarian Capsule 500 mg
# 2                         Brass Angle Deep - Plain, No.2
# 3      Cereal Flip Lid Container/Storage Jar - Assort...
# 4                     Creme Soft Soap - For Hands & Body
# 5                      Germ - Removal Multipurpose Wipes
# ...                                                  ...
# 27550         Wottagirl! Perfume Spray - Heaven, Classic
# 27551                                           Rosemary
# 27552                       Peri-Peri Sweet Potato Chips
# 27553                          Green Tea - Pure Original
# 27554                     United Dreams Go Far Deodorant
#
#                    category              sub_category  \
# 0          Beauty & Hygiene                 Hair Care
# 2      Cleaning & Household               Pooja Needs
# 3      Cleaning & Household      Bins & Bathroom Ware
# 4          Beauty & Hygiene          Bath & Hand Wash
# ...

# %%
sns.boxplot(df.sale_price,orient='h')
# Out:
# <Axes: xlabel='sale_price'>

# %%
df[df.sale_price>UL]
# Out:
# Empty DataFrame
# Columns: [product, category, sub_category, brand, sale_price, market_price, type, rating, description]
# Index: []

# %%
sns.boxplot(df.sale_price,orient='h')
# Out:
# <Axes: xlabel='sale_price'>

# %%
sns.lineplot(x=df.rating,y=df.market_price)
# Out:
# <Axes: xlabel='rating', ylabel='market_price'>

# %%
sns.barplot(x=df.brand.value_counts(),y=df.brand.value_counts().index)
# Out:
# <Axes: xlabel='count', ylabel='brand'>

# %%
import plotly.express as px

# %%
px.bar(x=df.brand.value_counts().index,y=df.brand.value_counts(),text=df.brand.value_counts(),template='plotly_dark')

# %%
df.brand.value_counts()
# Out:
# brand
# Fresho              638
# bb Royal            539
# BB Home             428
# DP                  250
# Fresho Signature    171
#                    ...
# Wellastrate           1
# Clean & Fresh         1
# Lal                   1
# Glint                 1
# Baron De Bercy        1
# Name: count, Length: 2313, dtype: int64

# %%
df.brand.value_counts().max()
# Out:
# 638

# %%
df.brand.value_counts().min()
# Out:
# 1

# %%
px.pie(values=df.category.value_counts(),names=df.category.value_counts().index)

# %%
px.bar(x=df.category.value_counts().index,y=df.category.value_counts(),text=df.category.value_counts(),template='plotly_dark')

# %%
df.category.value_counts().max()
# Out:
# 7867

# %%
df.category.value_counts().min()
# Out:
# 350
